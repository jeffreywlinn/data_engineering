# %%
import pandas as pd
import csv
import psycopg2
from sqlalchemy import create_engine
engine = create_engine('postgresql://postgres:RockyTonic87!@localhost/Project-1')

# %%
# Cleaning Header Table 2018
clean_header_2018 = r'C:\Users\linnj\Desktop\SkillStorm\Projects\Project-1\Shipping Data\S3Layer=Silver\Year=2018\clean-2018\clean-header-2018.csv'
df = pd.read_csv(clean_header_2018, delimiter=',')
df.columns = df.columns.str.title()
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head(5)
# Out:
#    Identifier Estimated_Arrival_Date Actual_Arrival_Date
# 0   201801010             2017-02-14          2017-02-15
# 1   201801011             2017-02-14          2017-02-15
# 2   201801012             2017-02-14          2017-02-15
# 3   201801013             2017-02-14          2017-02-15
# 4   201801014             2017-02-14          2017-02-15

# %%
df.to_csv(r'C:\Users\linnj\Desktop\SkillStorm\Projects\Project-1\Shipping Data\S3Layer=Silver\Year=2018\clean-2018\clean-header-2018.csv')

# %%
# 2019

# %%
raw_hazmat_2019 = r'C:\Users\linnj\Desktop\SkillStorm\Projects\Project-1\Shipping Data\S3Layer=Silver\Year=2019\raw-2019\ams__header_2019__202001080000.csv'
df = pd.read_csv(raw_hazmat_2019, delimiter=',')
df.columns = df.columns.str.title()

df.head(5)
# Out:
# C:\Users\linnj\AppData\Local\Temp\ipykernel_9152\1679116283.py:2: DtypeWarning: Columns (25,26,27,28,29,30) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(raw_hazmat_2019, delimiter=',')
#    Identifier Carrier_Code Vessel_Country_Code     Vessel_Name  \
# 0   201901010         OOLU                  FR  CMA CGM FIGARO
# 1   201901011         AEHS                  JP  MOL COMMITMENT
# 2   201901012         EXDO                  PA      EVER LUCKY
# 3   201901013         EXDO                  PA      EVER LUCKY
# 4   201901014         EXDO                  PA      EVER LUCKY
#
#           Port_Of_Unlading Estimated_Arrival_Date  \
# 0      Oakland, California             2017-10-08
# 1  Los Angeles, California             2018-01-28
# 2        Norfolk, Virginia             2018-03-28
# 3        Norfolk, Virginia             2018-03-28
# 4        Norfolk, Virginia             2018-03-28
#
# ...

# %%
df.drop(['Carrier_Code', 'Vessel_Country_Code', 'Vessel_Name', 'Port_Of_Unlading', 'Foreign_Port_Of_Lading_Qualifier', 'Foreign_Port_Of_Lading', 'Manifest_Quantity', 'Manifest_Unit'], axis=1, inplace=True)
df.head(5)
# Out:
#    Identifier Estimated_Arrival_Date  Weight Weight_Unit  Measurement  \
# 0   201901010             2017-10-08    9904   Kilograms            0
# 1   201901011             2018-01-28     857   Kilograms            0
# 2   201901012             2018-03-28   44599   Kilograms        12756
# 3   201901013             2018-03-28    9258   Kilograms         2539
# 4   201901014             2018-03-28   34760   Kilograms          136
#
#   Measurement_Unit Record_Status_Indicator Place_Of_Receipt  \
# 0     Cubic Meters                 Deleted          JAKARTA
# 1              NaN                 Deleted           MUMBAI
# 2     Cubic Meters                 Amended           GDYNIA
# 3     Cubic Meters                 Amended           GDYNIA
# 4     Cubic Meters                 Amended      BREMERHAVEN
#
#   Port_Of_Destination Foreign_Port_Of_Destination_Qualifier  ...  \
# 0                 NaN                                   NaN  ...
# ...

# %%
df.drop(['Weight', 'Weight_Unit', 'Measurement', 'Measurement_Unit', 'Record_Status_Indicator', 'Place_Of_Receipt', 'Port_Of_Destination', 'Foreign_Port_Of_Destination_Qualifier'],axis=1, inplace=True)
df.head(5)
# Out:
#    Identifier Estimated_Arrival_Date Foreign_Port_Of_Destination  \
# 0   201901010             2017-10-08                         NaN
# 1   201901011             2018-01-28                         NaN
# 2   201901012             2018-03-28                         NaN
# 3   201901013             2018-03-28                         NaN
# 4   201901014             2018-03-28                         NaN
#
#     Conveyance_Id_Qualifier   Conveyance_Id In_Bond_Entry_Type  \
# 0  IMO Number/Lloyds Number         9450600                NaN
# 1           Conveyance Name  MOL COMMITMENT                NaN
# 2  IMO Number/Lloyds Number         9604172                NaN
# 3  IMO Number/Lloyds Number         9604172                NaN
# 4  IMO Number/Lloyds Number         9604172                NaN
#
#   Mode_Of_Transportation Secondary_Notify_Party_1 Secondary_Notify_Party_2  \
# 0  Vessel, containerized                      NaN                      NaN
# ...

# %%
df.drop(['Foreign_Port_Of_Destination', 'Conveyance_Id_Qualifier', 'Conveyance_Id', 'In_Bond_Entry_Type', 'Mode_Of_Transportation', 'Secondary_Notify_Party_1'], axis=1, inplace=True)
df.head(5)
# Out:
#    Identifier Estimated_Arrival_Date Secondary_Notify_Party_2  \
# 0   201901010             2017-10-08                      NaN
# 1   201901011             2018-01-28                      NaN
# 2   201901012             2018-03-28                      NaN
# 3   201901013             2018-03-28                      NaN
# 4   201901014             2018-03-28                      NaN
#
#   Secondary_Notify_Party_3 Secondary_Notify_Party_4 Secondary_Notify_Party_5  \
# 0                      NaN                      NaN                      NaN
# 1                      NaN                      NaN                      NaN
# 2                      NaN                      NaN                      NaN
# 3                      NaN                      NaN                      NaN
# 4                      NaN                      NaN                      NaN
#
#   Secondary_Notify_Party_6 Secondary_Notify_Party_7 Secondary_Notify_Party_8  \
# ...

# %%
df.drop(['Secondary_Notify_Party_2', 'Secondary_Notify_Party_3', 'Secondary_Notify_Party_4', 'Secondary_Notify_Party_5', 'Secondary_Notify_Party_6', 'Secondary_Notify_Party_7', 'Secondary_Notify_Party_8'], axis=1, inplace=True)
df.head(5)
# Out:
#    Identifier Estimated_Arrival_Date  Secondary_Notify_Party_9  \
# 0   201901010             2017-10-08                       NaN
# 1   201901011             2018-01-28                       NaN
# 2   201901012             2018-03-28                       NaN
# 3   201901013             2018-03-28                       NaN
# 4   201901014             2018-03-28                       NaN
#
#    Secondary_Notify_Party_10 Actual_Arrival_Date
# 0                        NaN          2017-10-10
# 1                        NaN          2018-01-30
# 2                        NaN          2018-03-30
# 3                        NaN          2018-03-30
# 4                        NaN          2018-03-30

# %%
df.drop(['Secondary_Notify_Party_9', 'Secondary_Notify_Party_10'], axis=1, inplace=True)
df.head(5)
# Out:
#    Identifier Estimated_Arrival_Date Actual_Arrival_Date
# 0   201901010             2017-10-08          2017-10-10
# 1   201901011             2018-01-28          2018-01-30
# 2   201901012             2018-03-28          2018-03-30
# 3   201901013             2018-03-28          2018-03-30
# 4   201901014             2018-03-28          2018-03-30

# %%
df.to_csv(r'C:\Users\linnj\Desktop\SkillStorm\Projects\Project-1\Shipping Data\S3Layer=Silver\Year=2019\clean-2019\clean-header-2019.csv')

# %%
df.to_sql('header', engine, if_exists='append')
# Out:
# 574

# %%
# 2020

# %%
clean_header_2020 = r'C:\Users\linnj\Desktop\SkillStorm\Projects\Project-1\Shipping Data\S3Layer=Silver\Year=2020\clean-2020\clean-header-2020.csv'
df = pd.read_csv(clean_header_2020, delimiter=',')
df.columns = df.columns.str.title()
df.head(5)
# Out:
#    Unnamed: 0  Identifier Estimated_Arrival_Date Actual_Arrival_Date
# 0           0   202001060             2019-08-09          2019-08-09
# 1           1   202001061             2019-08-09          2019-08-09
# 2           2   202001062             2019-08-27          2019-08-27
# 3           3   202001063             2019-08-27          2019-08-27
# 4           4   202001064             2019-09-03          2019-09-06

# %%
df.drop('Unnamed: 0', axis=1, inplace=True)
df.head(5)
# Out:
#    Identifier Estimated_Arrival_Date Actual_Arrival_Date
# 0   202001060             2019-08-09          2019-08-09
# 1   202001061             2019-08-09          2019-08-09
# 2   202001062             2019-08-27          2019-08-27
# 3   202001063             2019-08-27          2019-08-27
# 4   202001064             2019-09-03          2019-09-06

# %%
df.to_csv(r'C:\Users\linnj\Desktop\SkillStorm\Projects\Project-1\Shipping Data\S3Layer=Silver\Year=2020\clean-2020\clean-header-2020.csv')

# %%
df.to_sql('header', engine, if_exists='append')
# Out:
# 956
